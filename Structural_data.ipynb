# %%
# Importando librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install mplstereonet
import mplstereonet as mpl
import sys
sys.version
# Out:
# ...
# '3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]'

# %%
# Importando ruta CSV desde Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Cargando la información desde CSV
faults_data = pd.read_csv('/content/Structural data_faults.csv')

# %%
# Ver encabezado
faults_data.head()
# Out:
#    strike_fault  dip_fault
# 0           227         80
# 1           123         80
# 2           220         85
# 3           256         78
# 4           228         84

# %%
# Proyectar datos estructurales
strikes = faults_data['strike_fault'].apply(lambda x: x if x <= 360 else x - 360).values
dips = faults_data['dip_fault'].values
fig, ax = mpl.subplots()
ax.grid()
_ = ax.plane(strikes, dips, c='red', )
